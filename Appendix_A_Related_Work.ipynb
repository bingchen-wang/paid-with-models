# %% [markdown]
# # Paid with Models: Optimal Contract Design for Collaborative Machine Learning
#
# ## Appendix A.1 Related Work
#
# This code generates the figure used in the proof.

# %%
# import relevant packages
import matplotlib.pyplot as plt
import numpy as np

# set the parameters
m = np.linspace(0.1,5, 100)
alpha = 0.75
tau = 0.5

# generate the function values
v = 0.4 * m + 4
u = 0.36 * np.sqrt(2*m) + 0.48*np.sqrt(5) + 0.16 * np.sqrt(10-2*m)

# plot the results

fig, ax = plt.subplots(1, 2, figsize = (7,3))

ax[0].plot(m, v)
ax[0].axvline(x=5, color = 'r', linestyle = '--')
ax[1].plot(m, u)
ax[1].axvline(x=405/97, color = 'r', linestyle = '--')
plt.show()
